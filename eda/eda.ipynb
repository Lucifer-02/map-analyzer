# %%
import polars as pl
import altair as alt
import matplotlib.pyplot as plt

# %%
data = pl.read_csv("./datasets/results/pop_compare.csv")
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = pl.read_csv("./datasets/results/pop_compare.csv")
#       2 data
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:119, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     114 @wraps(function)
#     115 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     116     _rename_keyword_argument(
#     117         old_name, new_name, kwargs, function.__qualname__, version
#     118     )
# --> 119     return function(*args, **kwargs)
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:119, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     114 @wraps(function)
#     115 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     116     _rename_keyword_argument(
#     117         old_name, new_name, kwargs, function.__qualname__, version
#     118     )
# --> 119     return function(*args, **kwargs)
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:119, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     114 @wraps(function)
#     115 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     116     _rename_keyword_argument(
#     117         old_name, new_name, kwargs, function.__qualname__, version
#     118     )
# --> 119     return function(*args, **kwargs)
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/io/csv/functions.py:539, in read_csv(source, has_header, columns, new_columns, separator, comment_prefix, quote_char, skip_rows, skip_lines, schema, schema_overrides, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, use_pyarrow, storage_options, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     531 else:
#     532     with prepare_file_arg(
#     533         source,
#     534         encoding=encoding,
#    (...)    537         storage_options=storage_options,
#     538     ) as data:
# --> 539         df = _read_csv_impl(
#     540             data,
#     541             has_header=has_header,
#     542             columns=columns if columns else projection,
#     543             separator=separator,
#     544             comment_prefix=comment_prefix,
#     545             quote_char=quote_char,
#     546             skip_rows=skip_rows,
#     547             skip_lines=skip_lines,
#     548             schema_overrides=schema_overrides,
#     549             schema=schema,
#     550             null_values=null_values,
#     551             missing_utf8_is_empty_string=missing_utf8_is_empty_string,
#     552             ignore_errors=ignore_errors,
#     553             try_parse_dates=try_parse_dates,
#     554             n_threads=n_threads,
#     555             infer_schema_length=infer_schema_length,
#     556             batch_size=batch_size,
#     557             n_rows=n_rows,
#     558             encoding=encoding if encoding == "utf8-lossy" else "utf8",
#     559             low_memory=low_memory,
#     560             rechunk=rechunk,
#     561             skip_rows_after_header=skip_rows_after_header,
#     562             row_index_name=row_index_name,
#     563             row_index_offset=row_index_offset,
#     564             eol_char=eol_char,
#     565             raise_if_empty=raise_if_empty,
#     566             truncate_ragged_lines=truncate_ragged_lines,
#     567             decimal_comma=decimal_comma,
#     568             glob=glob,
#     569         )
#     571 if new_columns:
#     572     return _update_columns(df, new_columns)
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/io/csv/functions.py:687, in _read_csv_impl(source, has_header, columns, separator, comment_prefix, quote_char, skip_rows, skip_lines, schema, schema_overrides, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     683         raise ValueError(msg)
#     685 projection, columns = parse_columns_arg(columns)
# --> 687 pydf = PyDataFrame.read_csv(
#     688     source,
#     689     infer_schema_length,
#     690     batch_size,
#     691     has_header,
#     692     ignore_errors,
#     693     n_rows,
#     694     skip_rows,
#     695     skip_lines,
#     696     projection,
#     697     separator,
#     698     rechunk,
#     699     columns,
#     700     encoding,
#     701     n_threads,
#     702     path,
#     703     dtype_list,
#     704     dtype_slice,
#     705     low_memory,
#     706     comment_prefix,
#     707     quote_char,
#     708     processed_null_values,
#     709     missing_utf8_is_empty_string,
#     710     try_parse_dates,
#     711     skip_rows_after_header,
#     712     parse_row_index_args(row_index_name, row_index_offset),
#     713     eol_char=eol_char,
#     714     raise_if_empty=raise_if_empty,
#     715     truncate_ragged_lines=truncate_ragged_lines,
#     716     decimal_comma=decimal_comma,
#     717     schema=schema,
#     718 )
#     719 return wrap_df(pydf)
#
# FileNotFoundError: No such file or directory (os error 2): ./datasets/results/pop_compare.csv

# %%
origin = pl.read_excel("./datasets/original/poi_original.xlsx")
origin["Population"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 origin = pl.read_excel("./datasets/original/poi_original.xlsx")
#       2 origin["Population"]
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:119, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     114 @wraps(function)
#     115 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     116     _rename_keyword_argument(
#     117         old_name, new_name, kwargs, function.__qualname__, version
#     118     )
# --> 119     return function(*args, **kwargs)
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:119, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     114 @wraps(function)
#     115 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     116     _rename_keyword_argument(
#     117         old_name, new_name, kwargs, function.__qualname__, version
#     118     )
# --> 119     return function(*args, **kwargs)
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/io/spreadsheet/functions.py:397, in read_excel(source, sheet_id, sheet_name, table_name, engine, engine_options, read_options, has_header, columns, schema_overrides, infer_schema_length, include_file_paths, drop_empty_rows, drop_empty_cols, raise_if_empty)
#     239 @deprecate_renamed_parameter("xlsx2csv_options", "engine_options", version="0.20.6")
#     240 @deprecate_renamed_parameter("read_csv_options", "read_options", version="0.20.7")
#     241 def read_excel(
#    (...)    257     raise_if_empty: bool = True,
#     258 ) -> pl.DataFrame | dict[str, pl.DataFrame]:
#     259     """
#     260     Read Excel spreadsheet data into a DataFrame.
#     261
#    (...)    395     ... )  # doctest: +SKIP
#     396     """
# --> 397     sources, read_multiple_workbooks = _sources(source)
#     398     frames: list[pl.DataFrame] | list[dict[str, pl.DataFrame]] = [  # type: ignore[assignment]
#     399         _read_spreadsheet(
#     400             src,
#    (...)    416         for src in sources
#     417     ]
#     418     return _unpack_read_results(
#     419         frames=frames,
#     420         read_multiple_workbooks=read_multiple_workbooks,
#     421     )
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/io/spreadsheet/functions.py:71, in _sources(source)
#      69     if not files:
#      70         msg = f"no workbook found at path {src!r}"
# ---> 71         raise FileNotFoundError(msg)
#      72     read_multiple_workbooks = True
#      73 else:
#
# FileNotFoundError: no workbook found at path './datasets/original/poi_original.xlsx'

# %%
data = data.with_columns(((pl.col("Official Estimate") - pl.col("Dataset Estimate"))*100/pl.col("Official Estimate")).alias("percent off"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = data.with_columns(((pl.col("Official Estimate") - pl.col("Dataset Estimate"))*100/pl.col("Official Estimate")).alias("percent off"))
#
# NameError: name 'data' is not defined

# %%
# Create a bar chart comparing Dataset Estimate and Official Estimate
plt.figure(figsize=(10, 6))
cities = data['DISTRICT']

# Plotting the estimates
plt.bar(cities, data['Dataset Estimate'], width=0.4, label='Dataset Estimate', align='center')
plt.bar(cities, data['Official Estimate'], width=0.4, label='Official Estimate', align='edge')

# Adding labels and title
plt.xlabel('District')
plt.ylabel('Population Estimate')
plt.title('Comparison of Dataset Estimate(Last updated 18 February 2023) vs. Official Estimate(02/2021)')
plt.xticks(rotation=90)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Create a bar chart comparing Dataset Estimate and Official Estimate
#       2 plt.figure(figsize=(10, 6))
# ----> 3 cities = data['DISTRICT']
#       5 # Plotting the estimates
#       6 plt.bar(cities, data['Dataset Estimate'], width=0.4, label='Dataset Estimate', align='center')
#
# NameError: name 'data' is not defined

# %%
data.select(pl.col("percent off")).mean()

# %%
full = pl.read_excel("./datasets/temp/around_poi_with_population.xlsx")
full
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 full = pl.read_excel("./datasets/temp/around_poi_with_population.xlsx")
#       2 full
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.10/site-packages/polars/_utils/deprecation.py:92, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      87 @wraps(function)
#      88 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#      89     _rename_keyword_argument(
#      90         old_name, new_name, kwargs, function.__qualname__, version
#      91     )
# ---> 92     return function(*args, **kwargs)
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.10/site-packages/polars/_utils/deprecation.py:92, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      87 @wraps(function)
#      88 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#      89     _rename_keyword_argument(
#      90         old_name, new_name, kwargs, function.__qualname__, version
#      91     )
# ---> 92     return function(*args, **kwargs)
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.10/site-packages/polars/io/spreadsheet/functions.py:394, in read_excel(source, sheet_id, sheet_name, table_name, engine, engine_options, read_options, has_header, columns, schema_overrides, infer_schema_length, include_file_paths, drop_empty_rows, drop_empty_cols, raise_if_empty)
#     236 @deprecate_renamed_parameter("xlsx2csv_options", "engine_options", version="0.20.6")
#     237 @deprecate_renamed_parameter("read_csv_options", "read_options", version="0.20.7")
#     238 def read_excel(
#    (...)
#     254     raise_if_empty: bool = True,
#     255 ) -> pl.DataFrame | dict[str, pl.DataFrame]:
#     256     """
#     257     Read Excel spreadsheet data into a DataFrame.
#     258
#    (...)
#     392     ... )  # doctest: +SKIP
#     393     """
# --> 394     sources, read_multiple_workbooks = _sources(source)
#     395     frames: list[pl.DataFrame] | list[dict[str, pl.DataFrame]] = [  # type: ignore[assignment]
#     396         _read_spreadsheet(
#     397             src,
#    (...)
#     413         for src in sources
#     414     ]
#     415     return _unpack_read_results(
#     416         frames=frames,
#     417         read_multiple_workbooks=read_multiple_workbooks,
#     418     )
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.10/site-packages/polars/io/spreadsheet/functions.py:68, in _sources(source)
#      66     if not files:
#      67         msg = f"no workbook found at path {src!r}"
# ---> 68         raise FileNotFoundError(msg)
#      69     read_multiple_workbooks = True
#      70 else:
#
# FileNotFoundError: no workbook found at path './datasets/temp/around_poi_with_population.xlsx'

# %%
import folium


m = folium.Map(location=(21.022672, 105.831461), zoom_start=14)

poi_id = 105
poi = full.filter(pl.col("poi_id").eq(poi_id)).to_dicts()

folium.Marker(
        location=[float(poi[0]["lat"]), float(poi[0]["lon"])],
        tooltip="Click me!",
        popup="",
        icon=folium.Icon(color="green"),
    ).add_to(m)

for place in poi:
    folium.Marker(
        location=[float(place["latitude"]), float(place["longitude"])],
        tooltip=place["title"],
        icon=folium.Icon(color="red"),
    ).add_to(m)
m

# %%
origin

# %%
full.join(origin, left_on='poi_id', right_on='Unique Identifier')["poi_id", "population", "Population"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 full.join(origin, left_on='poi_id', right_on='Unique Identifier')["poi_id", "population", "Population"]
#
# NameError: name 'full' is not defined

# %%
data
# Out:
# shape: (30, 6)
# ┌─────────┬────────┬──────────────┬────────┬──────────────────┬───────────────────┐
# │ COUNTRY ┆ CITY   ┆ DISTRICT     ┆ TYPE   ┆ Dataset Estimate ┆ Official Estimate │
# │ ---     ┆ ---    ┆ ---          ┆ ---    ┆ ---              ┆ ---               │
# │ str     ┆ str    ┆ str          ┆ str    ┆ f64              ┆ f64               │
# ╞═════════╪════════╪══════════════╪════════╪══════════════════╪═══════════════════╡
# │ Vietnam ┆ Hà Nội ┆ Đống Đa      ┆ Quận   ┆ 478.032          ┆ 401.7             │
# │ Vietnam ┆ Hà Nội ┆ Đông Anh     ┆ Huyện  ┆ 427.819          ┆ 374.9             │
# │ Vietnam ┆ Hà Nội ┆ Hoàng Mai    ┆ Quận   ┆ 424.121          ┆ 364.9             │
# │ Vietnam ┆ Hà Nội ┆ Hai Bà Trưng ┆ Quận   ┆ 369.003          ┆ 315.9             │
# │ Vietnam ┆ Hà Nội ┆ Chương Mỹ    ┆ Huyện  ┆ 364.014          ┆ 309.6             │
# │ …       ┆ …      ┆ …            ┆ …      ┆ …                ┆ …                 │
# │ Vietnam ┆ Hà Nội ┆ Thanh Oai    ┆ Huyện  ┆ 196.813          ┆ 185.4             │
# │ Vietnam ┆ Hà Nội ┆ Hoàn Kiếm    ┆ Quận   ┆ 182.718          ┆ 155.9             │
# │ Vietnam ┆ Hà Nội ┆ Đan Phượng   ┆ Huyện  ┆ 181.365          ┆ 154.3             │
# │ Vietnam ┆ Hà Nội ┆ Tây Hồ       ┆ Quận   ┆ 166.701          ┆ 152.8             │
# │ Vietnam ┆ Hà Nội ┆ Sơn Tây      ┆ Thị xã ┆ 161.501          ┆ 136.6             │
# └─────────┴────────┴──────────────┴────────┴──────────────────┴───────────────────┘

# %%
dataset_chart = alt.Chart(data).mark_bar().encode(
    x='DISTRICT:N',
    y='Dataset Estimate:Q'
)
official_chart = alt.Chart(data).mark_tick(color='red').encode(
    x='DISTRICT:N',
    y='Official Estimate:Q',
)
dataset_chart | official_chart
# Out:
# alt.HConcatChart(...)

# %%
df = pl.read_parquet("../datasets/results/vietnam.parquet")
df.unique(subset=["id"])
# Out:
# shape: (383_232, 17)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────┬────────┬────────────┬───────────┐
# │ query      ┆ link       ┆ title      ┆ category   ┆ … ┆ is_ATM ┆ id     ┆ created_da ┆ updated_d │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---    ┆ ---    ┆ te         ┆ ate       │
# │ str        ┆ str        ┆ str        ┆ str        ┆   ┆ i64    ┆ i64    ┆ ---        ┆ ---       │
# │            ┆            ┆            ┆            ┆   ┆        ┆        ┆ datetime[μ ┆ datetime[ │
# │            ┆            ┆            ┆            ┆   ┆        ┆        ┆ s]         ┆ μs]       │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════╪════════╪════════════╪═══════════╡
# │ lodging    ┆ https://ww ┆ Nhà Nghỉ   ┆ Lodge      ┆ … ┆ 0      ┆ 11555  ┆ 2025-05-15 ┆ 2025-05-1 │
# │            ┆ w.google.c ┆ Vân Anh    ┆            ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆            ┆            ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆            ┆            ┆   ┆        ┆        ┆            ┆           │
# │ supermarke ┆ https://ww ┆ Bama Mart  ┆ Supermarke ┆ … ┆ 0      ┆ 275027 ┆ 2025-05-15 ┆ 2025-05-1 │
# │ t          ┆ w.google.c ┆            ┆ t          ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆            ┆            ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆            ┆            ┆   ┆        ┆        ┆            ┆           │
# │ gas_statio ┆ https://ww ┆ Petrolimex ┆ Petrol     ┆ … ┆ 0      ┆ 357331 ┆ 2025-05-15 ┆ 2025-05-1 │
# │ n          ┆ w.google.c ┆ Gas        ┆ Station    ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆ Station    ┆            ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆ Store N…   ┆            ┆   ┆        ┆        ┆            ┆           │
# │ convenienc ┆ https://ww ┆ Tổng đại   ┆ Grocery    ┆ … ┆ 0      ┆ 265979 ┆ 2025-05-15 ┆ 2025-05-1 │
# │ e_store    ┆ w.google.c ┆ lý MC Mart ┆ store      ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆            ┆            ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆            ┆            ┆   ┆        ┆        ┆            ┆           │
# │ store      ┆ https://ww ┆ Cửa hàng   ┆ Store      ┆ … ┆ 0      ┆ 214207 ┆ 2025-05-15 ┆ 2025-05-1 │
# │            ┆ w.google.c ┆ mạnh hòa   ┆            ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆            ┆            ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆            ┆            ┆   ┆        ┆        ┆            ┆           │
# │ …          ┆ …          ┆ …          ┆ …          ┆ … ┆ …      ┆ …      ┆ …          ┆ …         │
# │ gym        ┆ https://ww ┆ King       ┆ Fitness    ┆ … ┆ 0      ┆ 311814 ┆ 2025-05-15 ┆ 2025-05-1 │
# │            ┆ w.google.c ┆ Fitness Hà ┆ center     ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆ Đông       ┆            ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆            ┆            ┆   ┆        ┆        ┆            ┆           │
# │ city_hall  ┆ https://ww ┆ Kazawa     ┆ City or    ┆ … ┆ 0      ┆ 15321  ┆ 2025-05-15 ┆ 2025-05-1 │
# │            ┆ w.google.c ┆ Tower      ┆ town hall  ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆            ┆            ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆            ┆            ┆   ┆        ┆        ┆            ┆           │
# │ art_galler ┆ https://ww ┆ Photocopy  ┆ Office     ┆ … ┆ 0      ┆ 369892 ┆ 2025-05-15 ┆ 2025-05-1 │
# │ y          ┆ w.google.c ┆ Đằng Trang ┆ supply     ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆            ┆ store      ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆            ┆            ┆   ┆        ┆        ┆            ┆           │
# │ pharmacy   ┆ https://ww ┆ Công Ty    ┆ Pharmacy   ┆ … ┆ 0      ┆ 27132  ┆ 2025-05-15 ┆ 2025-05-1 │
# │            ┆ w.google.c ┆ Dược Vật   ┆            ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆ Tư Y Tế    ┆            ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆            ┆            ┆   ┆        ┆        ┆            ┆           │
# │ home_goods ┆ https://ww ┆ Nội Thất   ┆ Furniture  ┆ … ┆ 0      ┆ 42852  ┆ 2025-05-15 ┆ 2025-05-1 │
# │ _store     ┆ w.google.c ┆ Bảo Nam cơ ┆ store      ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆ sở 3       ┆            ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆            ┆            ┆   ┆        ┆        ┆            ┆           │
# └────────────┴────────────┴────────────┴────────────┴───┴────────┴────────┴────────────┴───────────┘

# %%
# Out:
# shape: (383_232, 17)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────┬────────┬────────────┬───────────┐
# │ query      ┆ link       ┆ title      ┆ category   ┆ … ┆ is_ATM ┆ id     ┆ created_da ┆ updated_d │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---    ┆ ---    ┆ te         ┆ ate       │
# │ str        ┆ str        ┆ str        ┆ str        ┆   ┆ i64    ┆ i64    ┆ ---        ┆ ---       │
# │            ┆            ┆            ┆            ┆   ┆        ┆        ┆ datetime[μ ┆ datetime[ │
# │            ┆            ┆            ┆            ┆   ┆        ┆        ┆ s]         ┆ μs]       │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════╪════════╪════════════╪═══════════╡
# │ post_offic ┆ https://ww ┆ GHTK KHO   ┆ Post       ┆ … ┆ 0      ┆ 0      ┆ 2025-05-15 ┆ 2025-05-1 │
# │ e          ┆ w.google.c ┆ KHÁNH VĨNH ┆ office     ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆            ┆            ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆            ┆            ┆   ┆        ┆        ┆            ┆           │
# │ convenienc ┆ https://ww ┆ Lò mổ Đồng ┆ Butcher    ┆ … ┆ 0      ┆ 1      ┆ 2025-05-15 ┆ 2025-05-1 │
# │ e_store    ┆ w.google.c ┆ Lộc        ┆ shop       ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆            ┆            ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆            ┆            ┆   ┆        ┆        ┆            ┆           │
# │ bus_statio ┆ https://ww ┆ Bến Xe     ┆ Bus stop   ┆ … ┆ 0      ┆ 2      ┆ 2025-05-15 ┆ 2025-05-1 │
# │ n          ┆ w.google.c ┆ Khách Kỳ   ┆            ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆ Lâm        ┆            ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆            ┆            ┆   ┆        ┆        ┆            ┆           │
# │ atm        ┆ https://ww ┆ BIDV       ┆ ATM        ┆ … ┆ 1      ┆ 3      ┆ 2025-05-15 ┆ 2025-05-1 │
# │            ┆ w.google.c ┆            ┆            ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆            ┆            ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆            ┆            ┆   ┆        ┆        ┆            ┆           │
# │ school     ┆ https://ww ┆ Tran Dang  ┆ Middle     ┆ … ┆ 0      ┆ 4      ┆ 2025-05-15 ┆ 2025-05-1 │
# │            ┆ w.google.c ┆ Ninh       ┆ school     ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆ Secondary  ┆            ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆ Schoo…     ┆            ┆   ┆        ┆        ┆            ┆           │
# │ …          ┆ …          ┆ …          ┆ …          ┆ … ┆ …      ┆ …      ┆ …          ┆ …         │
# │ transit_st ┆ https://ww ┆ Xe Khách   ┆ Transporta ┆ … ┆ 0      ┆ 383227 ┆ 2025-05-15 ┆ 2025-05-1 │
# │ ation      ┆ w.google.c ┆ Mỹ Duyên   ┆ tion       ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆            ┆ service    ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆            ┆            ┆   ┆        ┆        ┆            ┆           │
# │ airport    ┆ https://ww ┆ Tan Son    ┆ Internatio ┆ … ┆ 0      ┆ 383228 ┆ 2025-05-15 ┆ 2025-05-1 │
# │            ┆ w.google.c ┆ Nhat Inter ┆ nal        ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆ national   ┆ airport    ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆ Air…       ┆            ┆   ┆        ┆        ┆            ┆           │
# │ movie_thea ┆ https://ww ┆ National   ┆ Movie      ┆ … ┆ 0      ┆ 383229 ┆ 2025-05-15 ┆ 2025-05-1 │
# │ ter        ┆ w.google.c ┆ Cinema     ┆ theater    ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆ Center     ┆            ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆            ┆            ┆   ┆        ┆        ┆            ┆           │
# │ atm        ┆ https://ww ┆ Sacombank  ┆ ATM        ┆ … ┆ 1      ┆ 383230 ┆ 2025-05-15 ┆ 2025-05-1 │
# │            ┆ w.google.c ┆            ┆            ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │            ┆ om/maps/pl ┆            ┆            ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆            ┆            ┆   ┆        ┆        ┆            ┆           │
# │ local_gove ┆ https://ww ┆ Thanh Tra  ┆ Local      ┆ … ┆ 0      ┆ 383231 ┆ 2025-05-15 ┆ 2025-05-1 │
# │ rnment_off ┆ w.google.c ┆ UBND Thành ┆ government ┆   ┆        ┆        ┆ 15:05:52.5 ┆ 5 15:05:5 │
# │ ice        ┆ om/maps/pl ┆ Phố Trà V… ┆ office     ┆   ┆        ┆        ┆ 08331      ┆ 2.508593  │
# │            ┆ …          ┆            ┆            ┆   ┆        ┆        ┆            ┆           │
# └────────────┴────────────┴────────────┴────────────┴───┴────────┴────────┴────────────┴───────────┘

# %%
import folium


m = folium.Map(location=(21.022672, 105.831461), zoom_start=14)

places = df.unique(subset=["id"]).sample(n=500).to_dicts()

folium.Marker(
        location=(21.022672, 105.831461),
        tooltip='PGD',
        icon=folium.Icon(color="red"),
    ).add_to(m)

for place in places:
    folium.Marker(
        location=[float(place["latitude"]), float(place["longitude"])],
        tooltip=place["title"],
        icon=folium.Icon(color="green"),
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_548e0518d6f33e472fe5b2f2468e30c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_548e0518d6f33e472fe5b2f2468e30c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_548e0518d6f33e472fe5b2f2468e30c3 = L.map(
#                 &quot;map_548e0518d6f33e472fe5b2f2468e30c3&quot;,
#                 {
#                     center: [21.022672, 105.831461],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8264cede61179f6d17a8a6c9b38c5c5a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8264cede61179f6d17a8a6c9b38c5c5a.addTo(map_548e0518d6f33e472fe5b2f2468e30c3);
#
#
#             var marker_22c0ae4bf5ad75be9073ed0d301a7479 = L.marker(
#                 [21.022672, 105.831461],
#                 {
# }
#             ).addTo(map_548e0518d6f33e472fe5b2f2468e30c3);
#
#
#             var icon_9b2afb456b4a00cdc9e28e8e0d80fe6f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_22c0ae4bf5ad75be9073ed0d301a7479.bindTooltip(
#                 `&lt;div&gt;
#                      PGD
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_22c0ae4bf5ad75be9073ed0d301a7479.setIcon(icon_9b2afb456b4a00cdc9e28e8e0d80fe6f);
#
#
#             var marker_f1d30e1a87a095c6fbfe883fa4b04e31 = L.marker(
#                 [21.831749, 105.172172],
#                 {
# }
#             ).addTo(map_548e0518d6f33e472fe5b2f2468e30c3);
#
#
#             var icon_946f2701f08b99fabdd2641febf66511 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_f1d30e1a87a095c6fbfe883fa4b04e31.bindTooltip(
#                 `&lt;div&gt;
#                      Bia Chiến thắng Cây Số Sáu
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_f1d30e1a87a095c6fbfe883fa4b04e31.setIcon(icon_946f2701f08b99fabdd2641febf66511);
#
#
#             var marker_859c040f80c60c58511a71bca77b13de = L.marker(
#                 [11.364332, 107.5667],
#                 {
# }
#             ).addTo(map_548e0518d6f33e472fe5b2f2468e30c3);
#
#
#             var icon_62e82acb68c97aa6d652ab547f48b602 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_859c040f80c60c58511a71bca77b13de.bindTooltip(
#                 `&lt;div&gt;
#                      Khu du lịch Thác 3 Tầng
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_859c040f80c60c58511a71bca77b13de.setIcon(icon_62e82acb68c97aa6d652ab547f48b602);
#
#
#             var marker_7e7a7d7ba254df5e17102207f9bb363f = L.marker(
#                 [18.506618, 105.36554],
#                 {
# }
#             ).addTo(map_548e0518d6f33e472fe5b2f2468e30c3);
#
#
#             var icon_d8c92328c212c75beafc97b0857a45e0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_7e7a7d7ba254df5e17102207f9bb363f.bindTooltip(
#                 `&lt;div&gt;
#                      Cửa hàng tạp hóa HOÀNG THÁI
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_7e7a7d7ba254df5e17102207f9bb363f.setIcon(icon_d8c92328c212c75beafc97b0857a45e0);
#
#
#             var marker_4b1633a0ec1e8e0cf328df1661490819 = L.marker(
#                 [10.358695, 106.343551],
#                 {
# }
#             ).addTo(map_548e0518d6f33e472fe5b2f2468e30c3);
#
#
#             var icon_dc876ccb672aac8afb19de37c4ab6ee7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot

# %%
import folium


m = folium.Map(location=(21.022672, 105.831461), zoom_start=14)

places = [
    {'title': 'vcb', 'latitude': 21.022672, 'longitude': 105.831461},
    {'title': 'school', 'latitude': 21.029672, 'longitude': 105.831461}

]

folium.Marker(
        location=(21.022672, 105.831461),
        tooltip='PGD',
        icon=folium.Icon(color="red"),
    ).add_to(m)
folium.Marker(
        location=(21.026672, 105.831461),
        tooltip='school',
        icon=folium.Icon(color="green"),
    ).add_to(m)
folium.Marker(
        location=(21.029672, 105.841461),
        tooltip='hospital',
        icon=folium.Icon(color="green"),
    ).add_to(m)
folium.Marker(
        location=(21.009672, 105.831461),
        tooltip='hospital',
        icon=folium.Icon(color="green"),
    ).add_to(m)
folium.Marker(
        location=(21.004672, 105.834461),
        tooltip='hospital',
        icon=folium.Icon(color="green"),
    ).add_to(m)
folium.Marker(
        location=(21.022672, 105.811461),
        tooltip='school',
        icon=folium.Icon(color="green"),
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_007a5c2acb5548650d194df1e522ca18 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_007a5c2acb5548650d194df1e522ca18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_007a5c2acb5548650d194df1e522ca18 = L.map(
#                 &quot;map_007a5c2acb5548650d194df1e522ca18&quot;,
#                 {
#                     center: [21.022672, 105.831461],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_384c68e597077e6bf0d7663a5b129f21 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_384c68e597077e6bf0d7663a5b129f21.addTo(map_007a5c2acb5548650d194df1e522ca18);
#
#
#             var marker_ae18e84a17995a1f89919349310e3dcd = L.marker(
#                 [21.022672, 105.831461],
#                 {
# }
#             ).addTo(map_007a5c2acb5548650d194df1e522ca18);
#
#
#             var icon_d281cef46da42767368fb435288eeb13 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_ae18e84a17995a1f89919349310e3dcd.bindTooltip(
#                 `&lt;div&gt;
#                      PGD
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_ae18e84a17995a1f89919349310e3dcd.setIcon(icon_d281cef46da42767368fb435288eeb13);
#
#
#             var marker_06e6234680b2a66e4e7db0bbda73b589 = L.marker(
#                 [21.026672, 105.831461],
#                 {
# }
#             ).addTo(map_007a5c2acb5548650d194df1e522ca18);
#
#
#             var icon_ec66dc4f55fa146d8a93722391885fac = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_06e6234680b2a66e4e7db0bbda73b589.bindTooltip(
#                 `&lt;div&gt;
#                      school
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_06e6234680b2a66e4e7db0bbda73b589.setIcon(icon_ec66dc4f55fa146d8a93722391885fac);
#
#
#             var marker_8fe51fbc5cee6964d5abaad72591f295 = L.marker(
#                 [21.029672, 105.841461],
#                 {
# }
#             ).addTo(map_007a5c2acb5548650d194df1e522ca18);
#
#
#             var icon_277bf3699a02df437447e0dc0779c67f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_8fe51fbc5cee6964d5abaad72591f295.bindTooltip(
#                 `&lt;div&gt;
#                      hospital
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_8fe51fbc5cee6964d5abaad72591f295.setIcon(icon_277bf3699a02df437447e0dc0779c67f);
#
#
#             var marker_e9dca09bf224031094091f6ff227daea = L.marker(
#                 [21.009672, 105.831461],
#                 {
# }
#             ).addTo(map_007a5c2acb5548650d194df1e522ca18);
#
#
#             var icon_4048e2643d431f5e4a69cf2af89e2891 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_e9dca09bf224031094091f6ff227daea.bindTooltip(
#                 `&lt;div&gt;
#                      hospital
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_e9dca09bf224031094091f6ff227daea.setIcon(icon_4048e2643d431f5e4a69cf2af89e2891);
#
#
#             var marker_4161f80f03de71844994314a436949ed = L.marker(
#                 [21.004672, 105.834461],
#                 {
# }
#             ).addTo(map_007a5c2acb5548650d194df1e522ca18);
#
#
#             var icon_ee292524581776cbf93256ace71231ec = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &qu

# %%
df = pl.read_csv("./pop.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pl.read_csv("./pop.csv")
#       2 df
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:119, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     114 @wraps(function)
#     115 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     116     _rename_keyword_argument(
#     117         old_name, new_name, kwargs, function.__qualname__, version
#     118     )
# --> 119     return function(*args, **kwargs)
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:119, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     114 @wraps(function)
#     115 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     116     _rename_keyword_argument(
#     117         old_name, new_name, kwargs, function.__qualname__, version
#     118     )
# --> 119     return function(*args, **kwargs)
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:119, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     114 @wraps(function)
#     115 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     116     _rename_keyword_argument(
#     117         old_name, new_name, kwargs, function.__qualname__, version
#     118     )
# --> 119     return function(*args, **kwargs)
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/io/csv/functions.py:539, in read_csv(source, has_header, columns, new_columns, separator, comment_prefix, quote_char, skip_rows, skip_lines, schema, schema_overrides, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, use_pyarrow, storage_options, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     531 else:
#     532     with prepare_file_arg(
#     533         source,
#     534         encoding=encoding,
#    (...)    537         storage_options=storage_options,
#     538     ) as data:
# --> 539         df = _read_csv_impl(
#     540             data,
#     541             has_header=has_header,
#     542             columns=columns if columns else projection,
#     543             separator=separator,
#     544             comment_prefix=comment_prefix,
#     545             quote_char=quote_char,
#     546             skip_rows=skip_rows,
#     547             skip_lines=skip_lines,
#     548             schema_overrides=schema_overrides,
#     549             schema=schema,
#     550             null_values=null_values,
#     551             missing_utf8_is_empty_string=missing_utf8_is_empty_string,
#     552             ignore_errors=ignore_errors,
#     553             try_parse_dates=try_parse_dates,
#     554             n_threads=n_threads,
#     555             infer_schema_length=infer_schema_length,
#     556             batch_size=batch_size,
#     557             n_rows=n_rows,
#     558             encoding=encoding if encoding == "utf8-lossy" else "utf8",
#     559             low_memory=low_memory,
#     560             rechunk=rechunk,
#     561             skip_rows_after_header=skip_rows_after_header,
#     562             row_index_name=row_index_name,
#     563             row_index_offset=row_index_offset,
#     564             eol_char=eol_char,
#     565             raise_if_empty=raise_if_empty,
#     566             truncate_ragged_lines=truncate_ragged_lines,
#     567             decimal_comma=decimal_comma,
#     568             glob=glob,
#     569         )
#     571 if new_columns:
#     572     return _update_columns(df, new_columns)
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/io/csv/functions.py:687, in _read_csv_impl(source, has_header, columns, separator, comment_prefix, quote_char, skip_rows, skip_lines, schema, schema_overrides, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     683         raise ValueError(msg)
#     685 projection, columns = parse_columns_arg(columns)
# --> 687 pydf = PyDataFrame.read_csv(
#     688     source,
#     689     infer_schema_length,
#     690     batch_size,
#     691     has_header,
#     692     ignore_errors,
#     693     n_rows,
#     694     skip_rows,
#     695     skip_lines,
#     696     projection,
#     697     separator,
#     698     rechunk,
#     699     columns,
#     700     encoding,
#     701     n_threads,
#     702     path,
#     703     dtype_list,
#     704     dtype_slice,
#     705     low_memory,
#     706     comment_prefix,
#     707     quote_char,
#     708     processed_null_values,
#     709     missing_utf8_is_empty_string,
#     710     try_parse_dates,
#     711     skip_rows_after_header,
#     712     parse_row_index_args(row_index_name, row_index_offset),
#     713     eol_char=eol_char,
#     714     raise_if_empty=raise_if_empty,
#     715     truncate_ragged_lines=truncate_ragged_lines,
#     716     decimal_comma=decimal_comma,
#     717     schema=schema,
#     718 )
#     719 return wrap_df(pydf)
#
# FileNotFoundError: No such file or directory (os error 2): ./pop.csv

# %%
# Create the visualization
chart = alt.Chart(df).mark_bar().encode(
    y=alt.Y('area', title="District"),
    x=alt.X('population', title='Population'),
    color=alt.Color('source', title="Source"),
    yOffset="source",
).properties(width=800, height=900)
chart
# Out:
# alt.Chart(...)

# %%
    df.pivot("source", index="area").select(
        (abs(((pl.col("tctk") - pl.col("ghs")) / pl.col("tctk")))*100).alias("ghs"),
        (abs(((pl.col("tctk") - pl.col("meta")) / pl.col("tctk")))*100).alias("meta"),
    ).describe()
# Out:
# shape: (9, 3)
# ┌────────────┬───────────┬───────────┐
# │ statistic  ┆ ghs       ┆ meta      │
# │ ---        ┆ ---       ┆ ---       │
# │ str        ┆ f64       ┆ f64       │
# ╞════════════╪═══════════╪═══════════╡
# │ count      ┆ 64.0      ┆ 64.0      │
# │ null_count ┆ 0.0       ┆ 0.0       │
# │ mean       ┆ 12.177615 ┆ 9.597109  │
# │ std        ┆ 12.916889 ┆ 9.512348  │
# │ min        ┆ 0.512046  ┆ 0.075875  │
# │ 25%        ┆ 4.407771  ┆ 4.63957   │
# │ 50%        ┆ 10.433251 ┆ 7.06713   │
# │ 75%        ┆ 16.286552 ┆ 11.857699 │
# │ max        ┆ 91.757263 ┆ 59.533221 │
# └────────────┴───────────┴───────────┘

# %%
import folium

df = pl.read_parquet("./long_bien.parquet")

m = folium.Map(location=(21.022672, 105.831461), zoom_start=14)

places = df.unique(subset=["id"]).sample(n=200).to_dicts()

for place in places:
    folium.Marker(
        location=[float(place["lat"]), float(place["lon"])],
        tooltip=place["name"],
        icon=folium.Icon(color="red"),
    ).add_to(m)
m
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 import folium
# ----> 3 df = pl.read_parquet("./long_bien.parquet")
#       5 m = folium.Map(location=(21.022672, 105.831461), zoom_start=14)
#       7 places = df.unique(subset=["id"]).sample(n=200).to_dicts()
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:119, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     114 @wraps(function)
#     115 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     116     _rename_keyword_argument(
#     117         old_name, new_name, kwargs, function.__qualname__, version
#     118     )
# --> 119     return function(*args, **kwargs)
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:119, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     114 @wraps(function)
#     115 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     116     _rename_keyword_argument(
#     117         old_name, new_name, kwargs, function.__qualname__, version
#     118     )
# --> 119     return function(*args, **kwargs)
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/io/parquet/functions.py:252, in read_parquet(source, columns, n_rows, row_index_name, row_index_offset, parallel, use_statistics, hive_partitioning, glob, schema, hive_schema, try_parse_hive_dates, rechunk, low_memory, storage_options, credential_provider, retries, use_pyarrow, pyarrow_options, memory_map, include_file_paths, allow_missing_columns)
#     249     else:
#     250         lf = lf.select(columns)
# --> 252 return lf.collect()
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:93, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      89         kwargs["engine"] = "in-memory"
#      91     del kwargs["streaming"]
# ---> 93 return function(*args, **kwargs)
#
# File /media/lucifer/STORAGE/IMPORTANT/map-analyzer/.venv/lib/python3.12/site-packages/polars/lazyframe/frame.py:2206, in LazyFrame.collect(self, type_coercion, _type_check, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, _check_order, _eager, **_kwargs)
#    2204 # Only for testing purposes
#    2205 callback = _kwargs.get("post_opt_callback", callback)
# -> 2206 return wrap_df(ldf.collect(engine, callback))
#
# FileNotFoundError: No such file or directory (os error 2): ./long_bien.parquet
#
# This error occurred with the following context stack:
# 	[1] 'parquet scan'
# 	[2] 'sink'

# %%
df
# Out:
# shape: (9_832, 6)
# ┌──────────────────┬───────────┬────────────┬──────────────────┬─────────────────┬─────────────────┐
# │ id               ┆ lat       ┆ lon        ┆ name             ┆ categories      ┆ address         │
# │ ---              ┆ ---       ┆ ---        ┆ ---              ┆ ---             ┆ ---             │
# │ str              ┆ f64       ┆ f64        ┆ str              ┆ str             ┆ str             │
# ╞══════════════════╪═══════════╪════════════╪══════════════════╪═════════════════╪═════════════════╡
# │ ChIJgRbT3pqpNTER ┆ 21.008869 ┆ 105.881819 ┆ Red River        ┆ campground,lodg ┆ Cự Khối,2V5J+GP │
# │ uz9pwVYx51c      ┆           ┆            ┆ Camping          ┆ ing,park,point_ ┆ Long Biên, Han… │
# │                  ┆           ┆            ┆                  ┆ …               ┆                 │
# │ ChIJu2ZjBXepNTER ┆ 21.0092   ┆ 105.878937 ┆ Bãi bồi vườn     ┆ tourist_attract ┆ 2V5H+MHM, Cầu   │
# │ HafpXpbRtfg      ┆           ┆            ┆ nhãn Sông Hồng   ┆ ion,point_of_in ┆ Vĩnh Tuy, Long  │
# │                  ┆           ┆            ┆                  ┆ …               ┆ B…              │
# │ ChIJYVeoRVepNTER ┆ 21.015227 ┆ 105.880996 ┆ Công ty Purastar ┆ general_contrac ┆ 2V8J+39X, Long  │
# │ uREHmFod2t0      ┆           ┆            ┆                  ┆ tor,point_of_in ┆ Biên            │
# │                  ┆           ┆            ┆                  ┆ …               ┆                 │
# │ ChIJgRbT3pqpNTER ┆ 21.008869 ┆ 105.881819 ┆ Red River        ┆ campground,lodg ┆ Cự Khối,2V5J+GP │
# │ uz9pwVYx51c      ┆           ┆            ┆ Camping          ┆ ing,park,point_ ┆ Long Biên, Han… │
# │                  ┆           ┆            ┆                  ┆ …               ┆                 │
# │ ChIJq6qqzk2pNTER ┆ 21.008374 ┆ 105.890319 ┆ Công Ty Cổ Phần  ┆ point_of_intere ┆ Xóm Bãi, Phường │
# │ rZa5WWCKh5o      ┆           ┆            ┆ Cơ Khí Và Vận …  ┆ st,establishmen ┆ Thanh Trì, Quậ… │
# │                  ┆           ┆            ┆                  ┆ …               ┆                 │
# │ …                ┆ …         ┆ …          ┆ …                ┆ …               ┆ …               │
# │ ChIJqzEJ5YOpNTER ┆ 21.07628  ┆ 105.902071 ┆ Máy phun sơn     ┆ point_of_intere ┆ 01 Phố Thanh    │
# │ zng27d8V-vI      ┆           ┆            ┆ công Nghiệp      ┆ st,establishmen ┆ Am, Thượng      │
# │                  ┆           ┆            ┆                  ┆ …               ┆ Thanh,…         │
# │ ChIJB1xSD1WpNTER ┆ 21.076255 ┆ 105.902077 ┆ Áo đoàn thanh    ┆ clothing_store, ┆ 1 Phố Thanh Am, │
# │ BTxOEBxE_U0      ┆           ┆            ┆ niên khoác gió   ┆ store,point_of_ ┆ Thượng Thanh,3… │
# │                  ┆           ┆            ┆ t…               ┆ …               ┆                 │
# │ ChIJtX8_UeepNTER ┆ 21.076255 ┆ 105.902077 ┆ Suli cafe        ┆ cafe,store,food ┆ 1 Phố Thanh Am, │
# │ J5t9fSJPOu8      ┆           ┆            ┆                  ┆ ,point_of_inter ┆ Thượng Thanh,3… │
# │                  ┆           ┆            ┆                  ┆ …               ┆                 │
# │ ChIJj_yCyClTNDER ┆ 21.075626 ┆ 105.901961 ┆ Viettel Store    ┆ store,point_of_ ┆ 28 Phố Thanh    │
# │ fp6CKPgEtDY      ┆           ┆            ┆                  ┆ interest,establ ┆ Am, Ứng         │
# │                  ┆           ┆            ┆                  ┆ …               ┆ Hoà,3WG2+…      │
# │ ChIJO6DhNLupNTER ┆ 21.068058 ┆ 105.899523 ┆ HG Fitness &     ┆ gym,health,poin ┆ 12 Ngõ 775 Ngô  │
# │ kzGZt9_cHvY      ┆           ┆            ┆ Yoga             ┆ t_of_interest,e ┆ Gia Tự, Đức     │
# │                  ┆           ┆            ┆                  ┆ …               ┆ Gia…            │
# └──────────────────┴───────────┴────────────┴──────────────────┴─────────────────┴─────────────────┘

# %%
df0 = pl.read_parquet("./datasets/raw/oss/bac_ninh_0_raw.parquet")
df = pl.read_parquet("./datasets/raw/oss/bac_ninh_0.parquet")

# %%
df0
# Out:
# shape: (763, 7)
# ┌──────────────┬──────────────┬──────────────┬──────────────┬───────────┬────────────┬─────────────┐
# │ link         ┆ title        ┆ category     ┆ categories   ┆ latitude  ┆ longitude  ┆ address     │
# │ ---          ┆ ---          ┆ ---          ┆ ---          ┆ ---       ┆ ---        ┆ ---         │
# │ str          ┆ str          ┆ str          ┆ str          ┆ f64       ┆ f64        ┆ str         │
# ╞══════════════╪══════════════╪══════════════╪══════════════╪═══════════╪════════════╪═════════════╡
# │ https://www. ┆ Sân vận động ┆ Stadium      ┆ Stadium      ┆ 20.973487 ┆ 106.195859 ┆ X5FW+98X    │
# │ google.com/m ┆ Thạch Lỗi    ┆              ┆              ┆           ┆            ┆ Sân vận     │
# │ aps/pl…      ┆              ┆              ┆              ┆           ┆            ┆ động Thạch  │
# │              ┆              ┆              ┆              ┆           ┆            ┆ Lỗ…         │
# │ https://www. ┆ Hang Day     ┆ Stadium      ┆ Stadium      ┆ 21.029845 ┆ 105.832969 ┆ 9 P. Trịnh  │
# │ google.com/m ┆ Stadium      ┆              ┆              ┆           ┆            ┆ Hoài Đức,   │
# │ aps/pl…      ┆              ┆              ┆              ┆           ┆            ┆ Cát Linh,…  │
# │ https://www. ┆ Sân vận động ┆ Stadium      ┆ Stadium      ┆ 20.97356  ┆ 106.151394 ┆ X5F2+CHC    │
# │ google.com/m ┆ xã Ngọc Liên ┆              ┆              ┆           ┆            ┆ Sân vận     │
# │ aps/pl…      ┆              ┆              ┆              ┆           ┆            ┆ động xã     │
# │              ┆              ┆              ┆              ┆           ┆            ┆ Ngọc …      │
# │ https://www. ┆ Sân vận động ┆ Stadium      ┆ Stadium      ┆ 20.951942 ┆ 106.142105 ┆ X42R+QRH    │
# │ google.com/m ┆ xã Hòa Phong ┆              ┆              ┆           ┆            ┆ Sân vận     │
# │ aps/pl…      ┆              ┆              ┆              ┆           ┆            ┆ động xã Hòa │
# │              ┆              ┆              ┆              ┆           ┆            ┆ P…          │
# │ https://www. ┆ Stadium      ┆ Stadium      ┆ Stadium      ┆ 20.790138 ┆ 106.238286 ┆ Q6RQ+383    │
# │ google.com/m ┆ Thanh Mien   ┆              ┆              ┆           ┆            ┆ Stadium     │
# │ aps/pl…      ┆ district     ┆              ┆              ┆           ┆            ┆ Thanh Mien  │
# │              ┆              ┆              ┆              ┆           ┆            ┆ di…         │
# │ …            ┆ …            ┆ …            ┆ …            ┆ …         ┆ …          ┆ …           │
# │ https://www. ┆ 15A Phương   ┆ Parking      ┆ Parking      ┆ 21.003802 ┆ 105.838659 ┆ 15A Phương  │
# │ google.com/m ┆ Mai          ┆ garage       ┆ garage       ┆           ┆            ┆ Mai, Đống   │
# │ aps/pl…      ┆              ┆              ┆              ┆           ┆            ┆ Đa, Hà Nộ…  │
# │ https://www. ┆ Điểm Đỗ xe   ┆ Parking lot  ┆ Parking lot  ┆ 21.036729 ┆ 105.85343  ┆ 2VP3+M9V    │
# │ google.com/m ┆ Trần Nhật    ┆              ┆              ┆           ┆            ┆ Điểm Đỗ xe  │
# │ aps/pl…      ┆ Duật         ┆              ┆              ┆           ┆            ┆ Trần Nhật … │
# │ https://www. ┆ OTOLIFE WORK ┆ Parking      ┆ Parking      ┆ 21.05289  ┆ 105.863625 ┆ 243 Ngọc    │
# │ google.com/m ┆ SHOP         ┆ garage       ┆ garage       ┆           ┆            ┆ Thuỵ, Ngọc  │
# │ aps/pl…      ┆              ┆              ┆              ┆           ┆            ┆ Thụy, Long… │
# │ https://www. ┆ Đền Đô       ┆ Parking lot  ┆ Parking lot  ┆ 21.108751 ┆ 105.959522 ┆ 4X55+GR2    │
# │ google.com/m ┆ Parking      ┆              ┆              ┆           ┆            ┆ Đền Đô      │
# │ aps/pl…      ┆              ┆              ┆              ┆           ┆            ┆ Parking, Lý │
# │              ┆              ┆              ┆              ┆           ┆            ┆ Th…         │
# │ https://www. ┆ Bãi đậu xe   ┆ Parking lot  ┆ Parking lot  ┆ 21.037289 ┆ 105.841179 ┆ 2RPR+WF7    │
# │ google.com/m ┆ Bộ Quốc      ┆              ┆              ┆           ┆            ┆ Bãi đậu xe  │
# │ aps/pl…      ┆ Phòng        ┆              ┆              ┆           ┆            ┆ Bộ Quốc Ph… │
# └──────────────┴──────────────┴──────────────┴──────────────┴───────────┴────────────┴─────────────┘

# %%
df
# Out:
# shape: (98, 7)
# ┌──────────────┬──────────────┬──────────────┬──────────────┬───────────┬────────────┬─────────────┐
# │ link         ┆ title        ┆ category     ┆ categories   ┆ latitude  ┆ longitude  ┆ address     │
# │ ---          ┆ ---          ┆ ---          ┆ ---          ┆ ---       ┆ ---        ┆ ---         │
# │ str          ┆ str          ┆ str          ┆ str          ┆ f64       ┆ f64        ┆ str         │
# ╞══════════════╪══════════════╪══════════════╪══════════════╪═══════════╪════════════╪═════════════╡
# │ https://www. ┆ Trạm bơm     ┆ Gas station  ┆ Gas station  ┆ 21.04366  ┆ 106.124746 ┆ 24VF+FV9    │
# │ google.com/m ┆ sông khoai   ┆              ┆              ┆           ┆            ┆ Trạm bơm    │
# │ aps/pl…      ┆              ┆              ┆              ┆           ┆            ┆ sông khoai, │
# │              ┆              ┆              ┆              ┆           ┆            ┆ …           │
# │ https://www. ┆ Tân Quyên Đồ ┆ Home goods   ┆ Home goods   ┆ 21.176459 ┆ 106.06052  ┆ P.Ninh Xá,  │
# │ google.com/m ┆ gia dụng     ┆ store        ┆ store        ┆           ┆            ┆ Bắc Ninh    │
# │ aps/pl…      ┆ (The Hou…    ┆              ┆              ┆           ┆            ┆             │
# │ https://www. ┆ Ngân Hàng    ┆ Bank         ┆ Bank         ┆ 21.052798 ┆ 106.175488 ┆ 353G+459    │
# │ google.com/m ┆ Phát Triển   ┆              ┆              ┆           ┆            ┆ Ngân Hàng   │
# │ aps/pl…      ┆ Nhà Đồng …   ┆              ┆              ┆           ┆            ┆ Phát Triển  │
# │              ┆              ┆              ┆              ┆           ┆            ┆ …           │
# │ https://www. ┆ 54           ┆ Bus stop     ┆ Bus stop     ┆ 21.158817 ┆ 106.038489 ┆ Xuân Ổ B,   │
# │ google.com/m ┆              ┆              ┆              ┆           ┆            ┆ Tp. Bắc     │
# │ aps/pl…      ┆              ┆              ┆              ┆           ┆            ┆ Ninh, Bắc   │
# │              ┆              ┆              ┆              ┆           ┆            ┆ Ni…         │
# │ https://www. ┆ Tu Son City  ┆ City         ┆ City         ┆ 21.113925 ┆ 105.955703 ┆ 4X74+H7G Tu │
# │ google.com/m ┆ Court        ┆ courthouse   ┆ courthouse   ┆           ┆            ┆ Son City    │
# │ aps/pl…      ┆              ┆              ┆              ┆           ┆            ┆ Court, Đ.…  │
# │ …            ┆ …            ┆ …            ┆ …            ┆ …         ┆ …          ┆ …           │
# │ https://www. ┆ Tòa Án Nhân  ┆ City         ┆ City         ┆ 21.055356 ┆ 106.171312 ┆ 8 Trần Hưng │
# │ google.com/m ┆ Dân Huyện    ┆ courthouse   ┆ courthouse   ┆           ┆            ┆ Đạo, Đông   │
# │ aps/pl…      ┆ Gia Bình     ┆              ┆              ┆           ┆            ┆ Cứu, Gia…   │
# │ https://www. ┆ Xưởng xe máy ┆ Parking lot  ┆ Parking lot  ┆ 21.031442 ┆ 106.124469 ┆ 24JF+HQG    │
# │ google.com/m ┆ Minh Chiến   ┆              ┆              ┆           ┆            ┆ Xưởng xe    │
# │ aps/pl…      ┆              ┆              ┆              ┆           ┆            ┆ máy Minh    │
# │              ┆              ┆              ┆              ┆           ┆            ┆ Chi…        │
# │ https://www. ┆ 54           ┆ Bus stop     ┆ Bus stop     ┆ 21.152774 ┆ 106.031912 ┆ Xuân Ổ A,   │
# │ google.com/m ┆              ┆              ┆              ┆           ┆            ┆ Tiên Du,    │
# │ aps/pl…      ┆              ┆              ┆              ┆           ┆            ┆ Bắc Ninh    │
# │ https://www. ┆ 57 Trần Phú  ┆ Bus stop     ┆ Bus stop     ┆ 21.11946  ┆ 105.96255  ┆ TX. Từ Sơn, │
# │ google.com/m ┆              ┆              ┆              ┆           ┆            ┆ Từ Sơn, Bắc │
# │ aps/pl…      ┆              ┆              ┆              ┆           ┆            ┆ Ninh        │
# │ https://www. ┆ Nhà Hàng     ┆ Seafood      ┆ Seafood      ┆ 21.038369 ┆ 106.092886 ┆ 234 Lạc     │
# │ google.com/m ┆ Phương Linh  ┆ restaurant   ┆ restaurant   ┆           ┆            ┆ Long Quân,  │
# │ aps/pl…      ┆ - Phuong …   ┆              ┆              ┆           ┆            ┆ Gia Đông, … │
# └──────────────┴──────────────┴──────────────┴──────────────┴───────────┴────────────┴─────────────┘

# %%
l = df0.select(pl.col("address")).to_series().to_list()

# %%
len([add for add in l if add is not None and "Bắc Ninh" in add])
# Out:
# 100

# %%
df0.filter(pl.col('title') == '54')
# Out:
# shape: (3, 7)
# ┌────────────────────┬───────┬──────────┬────────────┬───────────┬────────────┬────────────────────┐
# │ link               ┆ title ┆ category ┆ categories ┆ latitude  ┆ longitude  ┆ address            │
# │ ---                ┆ ---   ┆ ---      ┆ ---        ┆ ---       ┆ ---        ┆ ---                │
# │ str                ┆ str   ┆ str      ┆ str        ┆ f64       ┆ f64        ┆ str                │
# ╞════════════════════╪═══════╪══════════╪════════════╪═══════════╪════════════╪════════════════════╡
# │ https://www.google ┆ 54    ┆ Bus stop ┆ Bus stop   ┆ 21.158817 ┆ 106.038489 ┆ Xuân Ổ B, Tp. Bắc  │
# │ .com/maps/pl…      ┆       ┆          ┆            ┆           ┆            ┆ Ninh, Bắc Ni…      │
# │ https://www.google ┆ 54    ┆ Bus stop ┆ Bus stop   ┆ 21.152774 ┆ 106.031912 ┆ Xuân Ổ A, Tiên Du, │
# │ .com/maps/pl…      ┆       ┆          ┆            ┆           ┆            ┆ Bắc Ninh           │
# │ https://www.google ┆ 54    ┆ Bus stop ┆ Bus stop   ┆ 21.152819 ┆ 106.032145 ┆ Xuân Ổ A, Tiên Du, │
# │ .com/maps/pl…      ┆       ┆          ┆            ┆           ┆            ┆ Bắc Ninh           │
# └────────────────────┴───────┴──────────┴────────────┴───────────┴────────────┴────────────────────┘
